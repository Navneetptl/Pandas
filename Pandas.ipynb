# %%
import pandas as pd
import numpy as np

# %%
age=np.random.randint(16,80,20)
city=np.random.choice(["Mumbai","Chennai","Hyderabad","Pune","Delhi"],20)
default=np.random.choice([1,0],20)

# %%
my_data=list(zip(age,city,default))
my_data

# %%
df=pd.DataFrame(data=my_data,columns=['age','city','default'])
df

# %%
df=pd.DataFrame({'age':age,'city':city,'default':default})
df

# %%
file=r'E:\MY FOLDER\Pyhton Edvancer\data\data\loan_data_test.csv'
my_df=pd.read_csv(file)
my_df
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0    20093              5000                       5000   60 months
# 1    62445             18000                      18000   60 months
# 2    65248              7200                       7200   60 months
# 3    81822              7200                       7200   36 months
# 4    57923             22000                      22000   60 months
# ..     ...               ...                        ...         ...
# 295  24675             12000                      11975   60 months
# 296  69456              5000                       5000   36 months
# 297  97954              4375                       4375   36 months
# 298  36931             13600                      13600   60 months
# 299  34744              6000                       6000   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0                moving               12.59%    NY           RENT
# ...

# %%
my_df.head(50)
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0    20093              5000                       5000   60 months
# 1    62445             18000                      18000   60 months
# 2    65248              7200                       7200   60 months
# 3    81822              7200                       7200   36 months
# 4    57923             22000                      22000   60 months
# 5    33777              6000                          .   36 months
# 6    22573              9800                       9800   60 months
# 7    32044              6000                       6000   36 months
# 8     8127              3000                       3000   36 months
# 9     6067             17500                      17375   36 months
# 10   64769             25000                      25000   36 months
# 11   58924              9950                       9950   36 months
# 12   77733             10000                      10000   36 months
# ...

# %%
my_df.tail(10)
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 290  68487              5500                       5500   36 months
# 291  32008             14000                      14000   60 months
# 292  49690              1000                       1000   36 months
# 293  10059              3000                       3000   36 months
# 294   2749              8250                    8205.63   36 months
# 295  24675             12000                      11975   60 months
# 296  69456              5000                       5000   36 months
# 297  97954              4375                       4375   36 months
# 298  36931             13600                      13600   60 months
# 299  34744              6000                       6000   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 290  debt_consolidation               27.83%    WV            OWN
# 291  debt_consolidation                9.89%    CA       MORTGAGE
# ...

# %%
my_df.sample(5)
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 65   60943              7125                       7125   36 months
# 27   81840             25000                      25000   60 months
# 25   28201             10000                      10000   36 months
# 172  32875              6000                       6000   36 months
# 45   65485             19125                      19125   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 65   debt_consolidation                4.95%    MA           RENT
# 27   debt_consolidation                8.76%    NJ           RENT
# 25   debt_consolidation               20.27%    CT           RENT
# 172      major_purchase                4.74%    IL       MORTGAGE
# 45   debt_consolidation                9.10%    MA           RENT
#
#      Monthly.Income FICO.Range Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 65          2946.67    710-714                 6                      5015
# ...

# %%
my_df.columns
# Out:
# Index(['ID', 'Amount.Requested', 'Amount.Funded.By.Investors', 'Loan.Length',
#        'Loan.Purpose', 'Debt.To.Income.Ratio', 'State', 'Home.Ownership',
#        'Monthly.Income', 'FICO.Range', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Employment.Length'],
#       dtype='object')

# %%
my_df.dtypes
# Out:
# ID                                  int64
# Amount.Requested                    int64
# Amount.Funded.By.Investors         object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio               object
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# FICO.Range                         object
# Open.CREDIT.Lines                  object
# Revolving.CREDIT.Balance            int64
# Inquiries.in.the.Last.6.Months      int64
# Employment.Length                  object
# dtype: object

# %%
my_df.shape
# Out:
# (300, 14)

# %%
#ti view overall data structure of the dataframe, as in , 
#Total number of values in a dataframe, null values in each column and data type of columns
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              300 non-null    int64
#  1   Amount.Requested                300 non-null    int64
#  2   Amount.Funded.By.Investors      300 non-null    object
#  3   Loan.Length                     300 non-null    object
#  4   Loan.Purpose                    300 non-null    object
#  5   Debt.To.Income.Ratio            300 non-null    object
#  6   State                           300 non-null    object
#  7   Home.Ownership                  300 non-null    object
#  8   Monthly.Income                  300 non-null    float64
#  9   FICO.Range                      300 non-null    object
#  10  Open.CREDIT.Lines               300 non-null    object
#  11  Revolving.CREDIT.Balance        300 non-null    int64
# ...

# %%
#to view top 5 values of a dataframe
my_df.head(5)
# Out:
#       ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0  20093              5000                       5000   60 months
# 1  62445             18000                      18000   60 months
# 2  65248              7200                       7200   60 months
# 3  81822              7200                       7200   36 months
# 4  57923             22000                      22000   60 months
#
#          Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0              moving               12.59%    NY           RENT
# 1  debt_consolidation                4.93%    CA           RENT
# 2  debt_consolidation               25.16%    LA       MORTGAGE
# 3  debt_consolidation               17.27%    NY       MORTGAGE
# 4  debt_consolidation               18.28%    MI       MORTGAGE
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 0         4416.67    690-694                13                      7686
# ...

# %%
#Filtering data: to filter data add conditions as mentioned below

my_df[(my_df['Amount.Requested']==5000) & (my_df['Loan.Purpose']=='credit_card')]
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 88   19069              5000                       5000   36 months
# 110  16924              5000                    4947.35   60 months
#
#     Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  Monthly.Income  \
# 88   credit_card                3.33%    RI           RENT          9000.0
# 110  credit_card               10.80%    CA           RENT          6400.0
#
#     FICO.Range Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 88     735-739                 3                     12297
# 110    730-734                 8                      5783
#
#      Inquiries.in.the.Last.6.Months Employment.Length
# 88                                0         10+ years
# 110                               0          < 1 year

# %%
#to access diff columns of a dataframe
my_df[['Loan.Length','Amount.Requested','Loan.Purpose']]
# Out:
#     Loan.Length  Amount.Requested        Loan.Purpose
# 0     60 months              5000              moving
# 1     60 months             18000  debt_consolidation
# 2     60 months              7200  debt_consolidation
# 3     36 months              7200  debt_consolidation
# 4     60 months             22000  debt_consolidation
# ..          ...               ...                 ...
# 295   60 months             12000    home_improvement
# 296   36 months              5000  debt_consolidation
# 297   36 months              4375         credit_card
# 298   60 months             13600         credit_card
# 299   36 months              6000  debt_consolidation
#
# [300 rows x 3 columns]

# %%
#loc function: when using both condition and column names we need to use .loc with dataframe name
my_df.loc[(my_df['Home.Ownership']=='MORTGAGE') & (my_df['Monthly.Income']>5000),
       ['Home.Ownership','FICO.Range','Monthly.Income']]
# Out:
#     Home.Ownership FICO.Range  Monthly.Income
# 4         MORTGAGE    720-724         6083.33
# 16        MORTGAGE    720-724         5166.67
# 18        MORTGAGE    700-704         6250.00
# 21        MORTGAGE    680-684         5416.67
# 24        MORTGAGE    720-724         6250.00
# ..             ...        ...             ...
# 282       MORTGAGE    690-694        18750.00
# 285       MORTGAGE    730-734         6166.67
# 291       MORTGAGE    760-764         9000.00
# 295       MORTGAGE    705-709         7083.33
# 299       MORTGAGE    675-679         5184.75
#
# [76 rows x 3 columns]

# %%
#in order to negate a condition or drop rows on the basis of a conditon
#we just need to add a ~ symbol in front of the condition
#if 
my_df[~(my_df['Amount.Requested']==5000) & ~(my_df['Loan.Purpose']=='credit_card')]
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 1    62445             18000                      18000   60 months
# 2    65248              7200                       7200   60 months
# 3    81822              7200                       7200   36 months
# 4    57923             22000                      22000   60 months
# 5    33777              6000                          .   36 months
# ..     ...               ...                        ...         ...
# 291  32008             14000                      14000   60 months
# 292  49690              1000                       1000   36 months
# 293  10059              3000                       3000   36 months
# 295  24675             12000                      11975   60 months
# 299  34744              6000                       6000   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 1    debt_consolidation                4.93%    CA           RENT
# ...

# %%
#describe function: it will populate all the stastitical function for int and flot varaible column types
my_df.describe()
# Out:
#                   ID  Amount.Requested  Monthly.Income  \
# count     300.000000        300.000000      300.000000
# mean    48851.100000      11797.416667     5413.314367
# std     28668.362929       7402.104662     3030.583707
# min       476.000000       1000.000000     1000.000000
# 25%     27548.750000       6000.000000     3595.832500
# 50%     45611.000000      10000.000000     4816.500000
# 75%     72110.500000      16000.000000     6399.250000
# max    103426.000000      35000.000000    21666.670000
#
#        Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months
# count                300.000000                      300.000000
# mean               14654.030000                        0.966667
# std                15043.161582                        1.315799
# min                    0.000000                        0.000000
# 25%                 5470.250000                        0.000000
# 50%                10306.500000                        1.000000
# ...

# %%
# if you want to desribe all the attributes then below mentioned is the syntax where you need to specify include='all'.
#for categorical data it will pouplate unique, top and freq matrices. Other matrices will be nan
my_df.describe(include='all')
# Out:
#                    ID  Amount.Requested Amount.Funded.By.Investors  \
# count      300.000000        300.000000                        300
# unique            NaN               NaN                        163
# top               NaN               NaN                      10000
# freq              NaN               NaN                         18
# mean     48851.100000      11797.416667                        NaN
# std      28668.362929       7402.104662                        NaN
# min        476.000000       1000.000000                        NaN
# 25%      27548.750000       6000.000000                        NaN
# 50%      45611.000000      10000.000000                        NaN
# 75%      72110.500000      16000.000000                        NaN
# max     103426.000000      35000.000000                        NaN
#
#        Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# count          300                 300                  300   300
# ...

# %%
my_df.loc[100:105]
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 100  28257              6000                       6000   60 months
# 101  70843              8000                       8000   36 months
# 102  26608              3600                       3600   36 months
# 103   1046              5000                     527.49   36 months
# 104  84307             18000                      18000   60 months
# 105  15285             10000                       9975   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 100  debt_consolidation               18.39%    CA           RENT
# 101  debt_consolidation               14.31%    CA           RENT
# 102               other                  10%    NY           RENT
# 103  debt_consolidation               13.28%    NJ           RENT
# 104  debt_consolidation                  17%    CT           RENT
# 105      small_business                5.60%    VA           RENT
#
# ...

# %%
my_df.loc[100:105,['Amount.Requested','Loan.Length']]
# Out:
#      Amount.Requested Loan.Length
# 100              6000   60 months
# 101              8000   36 months
# 102              3600   36 months
# 103              5000   36 months
# 104             18000   60 months
# 105             10000   36 months

# %%
my_df.iloc[100:105,3:9]
# Out:
#         ID  Amount.Requested Amount.Funded.By.Investors Loan.Length  \
# 0    20093              5000                       5000   60 months
# 1    62445             18000                      18000   60 months
# 2    65248              7200                       7200   60 months
# 3    81822              7200                       7200   36 months
# 4    57923             22000                      22000   60 months
# ..     ...               ...                        ...         ...
# 295  24675             12000                      11975   60 months
# 296  69456              5000                       5000   36 months
# 297  97954              4375                       4375   36 months
# 298  36931             13600                      13600   60 months
# 299  34744              6000                       6000   36 months
#
#            Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0                moving               12.59%    NY           RENT
# ...

# %%
#to find unique values in a dataframe
my_df['State'].unique()
# Out:
# array(['NY', 'CA', 'LA', 'MI', 'NJ', 'MA', 'CO', 'NC', 'FL', 'MN', 'GA',
#        'OH', 'UT', 'IL', 'VA', 'CT', 'TX', 'DC', 'MD', 'NV', 'MO', 'AL',
#        'PA', 'IA', 'WA', 'OK', 'AK', 'KY', 'RI', 'OR', 'AR', 'WI', 'NM',
#        'AZ', 'DE', 'NH', 'WV', 'SC'], dtype=object)

# %%
#loading file with specified rows 
file=r'E:\MY FOLDER\Pyhton Edvancer\data\data\loan_data_test.csv'
my_df=pd.read_csv(file,nrows=20)

# %%
#loading file with specified rows 
file=r'E:\MY FOLDER\Pyhton Edvancer\data\data\loan_data_test.csv'
my_df=pd.read_csv(file,usecols=['ID','Amount.Requested'])
my_df
# Out:
#         ID  Amount.Requested
# 0    20093              5000
# 1    62445             18000
# 2    65248              7200
# 3    81822              7200
# 4    57923             22000
# ..     ...               ...
# 295  24675             12000
# 296  69456              5000
# 297  97954              4375
# 298  36931             13600
# 299  34744              6000
#
# [300 rows x 2 columns]

# %%
# loading file without header
#loading file with specified rows 
file=r'E:\MY FOLDER\Pyhton Edvancer\data\data\loan_data_test.csv'
my_df=pd.read_csv(file,header=None)
my_df
# Out:
#         0                 1                           2            3   \
# 0       ID  Amount.Requested  Amount.Funded.By.Investors  Loan.Length
# 1    20093              5000                        5000    60 months
# 2    62445             18000                       18000    60 months
# 3    65248              7200                        7200    60 months
# 4    81822              7200                        7200    36 months
# ..     ...               ...                         ...          ...
# 296  24675             12000                       11975    60 months
# 297  69456              5000                        5000    36 months
# 298  97954              4375                        4375    36 months
# 299  36931             13600                       13600    60 months
# 300  34744              6000                        6000    36 months
#
#                      4                     5      6               7   \
# ...

# %%
#to check the total number na in each column

my_df.isnull().sum()
# Out:
# ID                                0
# Amount.Requested                  0
# Amount.Funded.By.Investors        0
# Loan.Length                       0
# Loan.Purpose                      0
# Debt.To.Income.Ratio              0
# State                             0
# Home.Ownership                    0
# Monthly.Income                    0
# FICO.Range                        0
# Open.CREDIT.Lines                 0
# Revolving.CREDIT.Balance          0
# Inquiries.in.the.Last.6.Months    0
# Employment.Length                 9
# dtype: int64

# %%
file=r'E:\MY FOLDER\Pyhton Edvancer\data\data\loan_data_train.csv'
df=pd.read_csv(file)
df
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
df.isna().sum()
# Out:
# ID                                 1
# Amount.Requested                   1
# Amount.Funded.By.Investors         1
# Interest.Rate                      0
# Loan.Length                        1
# Loan.Purpose                       1
# Debt.To.Income.Ratio               1
# State                              1
# Home.Ownership                     1
# Monthly.Income                     3
# FICO.Range                         0
# Open.CREDIT.Lines                  4
# Revolving.CREDIT.Balance           3
# Inquiries.in.the.Last.6.Months     3
# Employment.Length                 69
# dtype: int64

# %%
new_df=df.dropna()
new_df
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
new_df.isna().sum()
# Out:
# ID                                0
# Amount.Requested                  0
# Amount.Funded.By.Investors        0
# Interest.Rate                     0
# Loan.Length                       0
# Loan.Purpose                      0
# Debt.To.Income.Ratio              0
# State                             0
# Home.Ownership                    0
# Monthly.Income                    0
# FICO.Range                        0
# Open.CREDIT.Lines                 0
# Revolving.CREDIT.Balance          0
# Inquiries.in.the.Last.6.Months    0
# Employment.Length                 0
# dtype: int64

# %%
#to drop rows with all the columns as na
df.dropna(how='all')
#it will delete the rows where all the caloumn values are na
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
file=r'E:\MY FOLDER\Pyhton Edvancer\data\data\loan_data_train.csv'
df=pd.read_csv(file)
df
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                                 1
# Amount.Requested                   1
# Amount.Funded.By.Investors         1
# Interest.Rate                      0
# Loan.Length                        1
# Loan.Purpose                       1
# Debt.To.Income.Ratio               1
# State                              1
# Home.Ownership                     1
# Monthly.Income                     3
# FICO.Range                         0
# Open.CREDIT.Lines                  4
# Revolving.CREDIT.Balance           3
# Inquiries.in.the.Last.6.Months     3
# Employment.Length                 69
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2199 non-null   float64
#  1   Amount.Requested                2199 non-null   object
#  2   Amount.Funded.By.Investors      2199 non-null   object
#  3   Interest.Rate                   2200 non-null   object
#  4   Loan.Length                     2199 non-null   object
#  5   Loan.Purpose                    2199 non-null   object
#  6   Debt.To.Income.Ratio            2199 non-null   object
#  7   State                           2199 non-null   object
#  8   Home.Ownership                  2199 non-null   object
#  9   Monthly.Income                  2197 non-null   float64
#  10  FICO.Range                      2200 non-null   object
#  11  Open.CREDIT.Lines               2196 non-null   object
# ...

# %%
#filling na values with mean
df['Monthly.Income'].fillna(df['Monthly.Income'].mean(),inplace=True)
df.isna().sum()
# Out:
# ID                                 1
# Amount.Requested                   1
# Amount.Funded.By.Investors         1
# Interest.Rate                      0
# Loan.Length                        1
# Loan.Purpose                       1
# Debt.To.Income.Ratio               1
# State                              1
# Home.Ownership                     1
# Monthly.Income                     0
# FICO.Range                         0
# Open.CREDIT.Lines                  4
# Revolving.CREDIT.Balance           3
# Inquiries.in.the.Last.6.Months     3
# Employment.Length                 69
# dtype: int64

# %%
#Removing or droping an column
df.drop(['Open.CREDIT.Lines'],inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-b73202784472> in <module>
#       1 #Removing or droping an column
# ----> 2 df.drop(['Open.CREDIT.Lines'],inplace=True,axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df.isna().sum()
# Out:
# ID                                 1
# Amount.Requested                   1
# Amount.Funded.By.Investors         1
# Interest.Rate                      0
# Loan.Length                        1
# Loan.Purpose                       1
# Debt.To.Income.Ratio               1
# State                              1
# Home.Ownership                     1
# Monthly.Income                     0
# FICO.Range                         0
# Revolving.CREDIT.Balance           3
# Inquiries.in.the.Last.6.Months     3
# Employment.Length                 69
# dtype: int64

# %%
df
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     79542.0            25000                      25000        18.49%
# 1     75473.0            19750                      19750        17.27%
# 2     67265.0             2100                       2100        14.33%
# 3     80167.0            28000                      28000        16.29%
# 4     17240.0            24250                   17431.82        12.23%
# ...       ...              ...                        ...           ...
# 2195  74047.0            30000                      30000        23.28%
# 2196  63768.0             4200                       4200        14.33%
# 2197  94545.0            19800                      19775        15.31%
# 2198  53635.0            18000                      18000        20.99%
# 2199  67953.0             7550                       7550        10.16%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
df.drop(['ID'],inplace=True,axis=1)
df
# Out:
#      Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 0               25000                      25000        18.49%   60 months
# 1               19750                      19750        17.27%   60 months
# 2                2100                       2100        14.33%   36 months
# 3               28000                      28000        16.29%   36 months
# 4               24250                   17431.82        12.23%   60 months
# ...               ...                        ...           ...         ...
# 2195            30000                      30000        23.28%   60 months
# 2196             4200                       4200        14.33%   60 months
# 2197            19800                      19775        15.31%   60 months
# 2198            18000                      18000        20.99%   60 months
# 2199             7550                       7550        10.16%   36 months
#
# ...

# %%
df.groupby('Home.Ownership').mean()
# Out:
#                 Monthly.Income  Inquiries.in.the.Last.6.Months
# Home.Ownership
# MORTGAGE           6659.017377                        1.003933
# NONE               5727.459290                             NaN
# OTHER              6024.917500                        0.750000
# OWN                4790.691864                        0.802260
# RENT               4941.776266                        0.807615

# %%
df.groupby('Loan.Purpose').mean()['Monthly.Income']
# Out:
# Loan.Purpose
# car                   5669.823318
# credit_card           5407.883122
# debt_consolidation    5753.018482
# educational           4263.255714
# home_improvement      6753.197926
# house                 6248.056316
# major_purchase        6576.647024
# medical               5114.621538
# moving                5372.837600
# other                 5217.292410
# renewable_energy      2738.890000
# small_business        5840.215000
# vacation              6328.935000
# wedding               5812.862000
# Name: Monthly.Income, dtype: float64

# %%
df.groupby(['Loan.Purpose','Home.Ownership']).mean()['Monthly.Income']
# Out:
# Loan.Purpose        Home.Ownership
# car                 MORTGAGE          7687.321723
#                     OWN               4066.666000
#                     RENT              4527.141304
# credit_card         MORTGAGE          6247.100581
#                     OTHER             6125.000000
#                     OWN               3908.552571
#                     RENT              4892.601304
# debt_consolidation  MORTGAGE          6665.602574
#                     OTHER             5924.835000
#                     OWN               4804.704545
#                     RENT              4944.298625
# educational         MORTGAGE          5467.750000
#                     OWN               3112.833333
#                     RENT              3834.721667
# home_improvement    MORTGAGE          6556.564519
#                     OWN               6986.666250
#                     RENT              7867.490000
# house               MORTGAGE          5183.332000
# ...

# %%
df.shape
# Out:
# (2200, 13)

# %%
df.columns
# Out:
# Index(['Amount.Requested', 'Amount.Funded.By.Investors', 'Interest.Rate',
#        'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio', 'State',
#        'Home.Ownership', 'Monthly.Income', 'FICO.Range',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Employment.Length'],
#       dtype='object')

# %%
#to check frequency of each value in a column with categorical value
df['Home.Ownership'].value_counts()
# Out:
# MORTGAGE    1018
# RENT         999
# OWN          177
# OTHER          4
# NONE           1
# Name: Home.Ownership, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['VA', 'NY', 'LA', 'NV', 'OH', 'CA', 'IL', 'NC', 'NJ', 'WA', 'CT',
#        'AK', 'CO', 'MA', 'TX', 'VT', 'OK', 'FL', 'NH', 'GA', 'MN', 'MD',
#        'WY', 'PA', 'AL', 'AZ', 'SC', 'MI', 'OR', 'RI', 'NM', 'MO', 'WI',
#        'KY', 'UT', 'AR', 'WV', 'DE', 'MT', 'KS', 'DC', 'SD', 'HI', 'IN',
#        'MS', nan, '.'], dtype=object)

# %%
# to sort based on the values of the column 
df.sort_values('Amount.Requested',ascending=False)
# Out:
#      Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Length  \
# 984              9950                       9950        14.33%   36 months
# 1957             9950                       9925        13.11%   36 months
# 972              9800                       9800        19.69%   60 months
# 1287             9800                       9775         5.99%   36 months
# 1135             9800                     9747.5         7.29%   36 months
# ...               ...                        ...           ...         ...
# 1791                .                      15875        14.33%   36 months
# 1357                .                      12000        10.16%   36 months
# 371                 .                       1850        12.49%   36 months
# 1991                .                       7000         6.91%   36 months
# 1676              NaN                      10000        11.71%   36 months
#
# ...

# %%
df['Monthly.Income']=df['Monthly.Income'].astype(int)

# %%
df[['Monthly.Income','Home.Ownership']]
# Out:
#       Monthly.Income Home.Ownership
# 0               8606       MORTGAGE
# 1               6737       MORTGAGE
# 2               1000            OWN
# 3               7083       MORTGAGE
# 4               5833       MORTGAGE
# ...              ...            ...
# 2195            7083       MORTGAGE
# 2196            3850           RENT
# 2197            6666       MORTGAGE
# 2198            9051           RENT
# 2199            8333       MORTGAGE
#
# [2200 rows x 2 columns]

# %%
df['State'].replace("NY",'Replaced')
# Out:
# 0             VA
# 1       Replaced
# 2             LA
# 3             NV
# 4             OH
#           ...
# 2195          IL
# 2196          NJ
# 2197          IL
# 2198          CA
# 2199          CA
# Name: State, Length: 2200, dtype: object

# %%
#Rename: to rename columns
df.rename(columns={'Loan.Length':'Loan.Tenure'},inplace=True)

# %%
df.head()
# Out:
#   Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Tenure  \
# 0            25000                      25000        18.49%   60 months
# 1            19750                      19750        17.27%   60 months
# 2             2100                       2100        14.33%   36 months
# 3            28000                      28000        16.29%   36 months
# 4            24250                   17431.82        12.23%   60 months
#
#          Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0  debt_consolidation               27.56%    VA       MORTGAGE
# 1  debt_consolidation               13.39%    NY       MORTGAGE
# 2      major_purchase                3.50%    LA            OWN
# 3         credit_card               19.62%    NV       MORTGAGE
# 4         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly.Income FICO.Range Revolving.CREDIT.Balance  \
# 0            8606    720-724                    15210
# ...

# %%
#concatinating two dataframes row wise
d1={'Name':['Navneet','Lalu','Harsh'],'Roll No.':[1,2,3],'City':['Delhi','Jamshedpur','Mumbai']}
new_datafr=pd.DataFrame(d1)
new_datafr
# Out:
#       Name  Roll No.        City
# 0  Navneet         1       Delhi
# 1     Lalu         2  Jamshedpur
# 2    Harsh         3      Mumbai

# %%
d2={'Name':['Kunal','Abhshek'],'Roll No.':[1,5],'City':['Chennai','Jaipur']}
new_datafr_1=pd.DataFrame(d2)
new_datafr_1
# Out:
#       Name  Roll No.     City
# 0    Kunal         1  Chennai
# 1  Abhshek         5   Jaipur

# %%
df3=pd.concat([new_datafr,new_datafr_1],ignore_index=True)

# %%
df3
# Out:
#       Name  Roll No.        City
# 0  Navneet         1       Delhi
# 1     Lalu         2  Jamshedpur
# 2    Harsh         3      Mumbai
# 3    Kunal         1     Chennai
# 4  Abhshek         5      Jaipur

# %%
d3={'City1':['Chennai','Jaipur','asshf','kjfhfg','olkdie']}
df4=pd.DataFrame(d3)
df4
# Out:
#      City1
# 0  Chennai
# 1   Jaipur
# 2    asshf
# 3   kjfhfg
# 4   olkdie

# %%
#concatinating two dataframes column wise
df6=pd.concat([df3,df4],axis=1)

# %%
df6
# Out:
#       Name  Roll No.        City    City1
# 0  Navneet         1       Delhi  Chennai
# 1     Lalu         2  Jamshedpur   Jaipur
# 2    Harsh         3      Mumbai    asshf
# 3    Kunal         1     Chennai   kjfhfg
# 4  Abhshek         5      Jaipur   olkdie

# %%
#inserting column in a dataframe
df6.insert(1,'Age',[26,27,28,45,43])
df6
# Out:
#       Name  Age  Roll No.        City    City1
# 0  Navneet   26         1       Delhi  Chennai
# 1     Lalu   27         2  Jamshedpur   Jaipur
# 2    Harsh   28         3      Mumbai    asshf
# 3    Kunal   45         1     Chennai   kjfhfg
# 4  Abhshek   43         5      Jaipur   olkdie

# %%
#removing duplicates from the dataframe
df6.drop_duplicates(subset=['Roll No.'])
# Out:
#       Name  Age  Roll No.        City    City1
# 0  Navneet   26         1       Delhi  Chennai
# 1     Lalu   27         2  Jamshedpur   Jaipur
# 2    Harsh   28         3      Mumbai    asshf
# 4  Abhshek   43         5      Jaipur   olkdie

# %%
#Random sampling the dataframe
df.sample(1000)
# Out:
#      Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Tenure  \
# 122             35000                      35000        21.00%   36 months
# 321             12000                      12000        21.98%   60 months
# 1010            12000                      12000        17.99%   60 months
# 144             10000                      10000         7.62%   36 months
# 1974            10000                      10000         6.03%   36 months
# ...               ...                        ...           ...         ...
# 377              5000                       5000        12.68%   36 months
# 1285             8000                       7875        11.48%   36 months
# 2071            12000                      12000        12.99%   60 months
# 1740             8000                       8000        14.09%   36 months
# 471             20000                      20000        19.72%   60 months
#
# ...

# %%
#you can also specify the percentage of entire population
df.sample(frac=0.20)
# Out:
#      Amount.Requested Amount.Funded.By.Investors Interest.Rate Loan.Tenure  \
# 2043             2500                       2500        11.99%   36 months
# 144             10000                      10000         7.62%   36 months
# 1345             7000                       7000        16.29%   36 months
# 2032            12800                      12800        12.12%   36 months
# 1141             5000                       5000         7.62%   36 months
# ...               ...                        ...           ...         ...
# 1875            20000                      20000        21.49%   36 months
# 688              4000                       3975        14.96%   36 months
# 48               5000                       5000         9.32%   36 months
# 1568             8000                       8000        10.38%   36 months
# 1419            19600                      19575        16.29%   36 months
#
# ...
